# %% [markdown]
# # Part I. ETL Pipeline for Pre-Processing the Files

# %% [markdown]
# ## PLEASE RUN THE FOLLOWING CODE FOR PRE-PROCESSING THE FILES

# %% [markdown]
# #### Import Python packages

# %%
# Import Python packages 
import pandas as pd
import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %% [markdown]
# #### Creating list of filepaths to process original event csv data files

# %%
# checking your current working directory
print(os.getcwd())

# Get your current folder and subfolder event data
filepath = os.getcwd() + '/event_data'

# Create a for loop to create a list of files and collect each filepath
for root, dirs, files in os.walk(filepath):
    
# join the file path and roots with the subdirectories using glob
    file_path_list = glob.glob(os.path.join(root,'*'))
    print(file_path_list)
# Out:
# /home/workspace/udacity-nanodegree-data-eng/project2
# ['/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-27-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-04-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-07-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-09-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-19-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-05-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-22-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-16-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-26-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-24-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-29-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-15-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-20-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-06-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-18-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-21-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-10-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-23-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-02-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-28-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-03-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-13-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-30-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-12-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-01-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-14-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-25-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-08-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-17-events.csv', '/home/workspace/udacity-nanodegree-data-eng/project2/event_data/2018-11-11-events.csv']

# %% [markdown]
# #### Processing the files to create the data file csv that will be used for Apache Casssandra tables

# %%
# initiating an empty list of rows that will be generated from each file
full_data_rows_list = [] 
    
# for every filepath in the file path list 
for f in file_path_list:

# reading csv file 
    with open(f, 'r', encoding = 'utf8', newline='') as csvfile: 
        # creating a csv reader object 
        csvreader = csv.reader(csvfile) 
        next(csvreader)
        
 # extracting each data row one by one and append it        
        for line in csvreader:
            #print(line)
            full_data_rows_list.append(line) 
            
# uncomment the code below if you would like to get total number of rows 
print(len(full_data_rows_list))
# uncomment the code below if you would like to check to see what the list of event data rows will look like
print(full_data_rows_list)

# creating a smaller event data csv file called event_datafile_full csv that will be used to insert data into the \
# Apache Cassandra tables
csv.register_dialect('myDialect', quoting=csv.QUOTE_ALL, skipinitialspace=True)

with open('event_datafile_new.csv', 'w', encoding = 'utf8', newline='') as f:
    writer = csv.writer(f, dialect='myDialect')
    writer.writerow(['artist','firstName','gender','itemInSession','lastName','length',\
                'level','location','sessionId','song','userId'])
    for row in full_data_rows_list:
        if (row[0] == ''):
            continue
        writer.writerow((row[0], row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[12], row[13], row[16]))
# Out:
# 8056
# [['Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner', 'Logged In', 'Mohammad', 'M', '0', 'Rodriguez', '277.15873', 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', 'PUT', 'NextSong', '1.54051E+12', '961', 'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)', '200', '1.54328E+12', '88'], ['Jimi Hendrix', 'Logged In', 'Mohammad', 'M', '1', 'Rodriguez', '239.82975', 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', 'PUT', 'NextSong', '1.54051E+12', '961', 'Woodstock Inprovisation', '200', '1.54328E+12', '88'], ['Building 429', 'Logged In', 'Mohammad', 'M', '2', 'Rodriguez', '300.61669', 'paid', 'Sacramento--Roseville--Arden-Arcade, CA', 'PUT', 'NextSong', '1.54051E+12', '961', 'Majesty (LP Version)', '200', '1.54328E+12', '88'], ["The B-52's", 'Logged In', 'Gianna', 'F', '0', 'Jones', '321.54077', 'free', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', '1.54087E+12', '107', 'Love Shack', '200', '1.54328E+12', '38'], ['Die Mooskirchner', 'Logged In', 'Gianna', 'F', '1', 'Jones', '169.29914', 'free', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', '1.54087E+12', '107', "Frisch und g'sund", '200', '1.54328E+12', '38'], ['Carrie Underwood', 'Logged In', 'Gianna', 'F', '2', 'Jones', '195.70893', 'free', 'New York-Newark-Jersey City, NY-NJ-PA', 'PUT', 'NextSong', '1.54087E+12', '107', 'Look At Me', '200', '1.54328E+12', '38'], ['', 'Logged In', 'Evelin', 'F', '0', 'Ayala', '', 'free', 'Milwaukee-Waukesha-West Allis, WI', 'GET', 'Home', '1.54101E+12', '586', '', '200', '1.54329E+12', '34'], ['No Te Va Gustar', 'Logged In', 'Kaylee', 'F', '0', 'Summers', '246.43873', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', '1.54034E+12', '833', 'Ya EntendÃ\x83Â\xad', '200', '1.54329E+12', '8'], ['The Velvet Underground / Nico', 'Logged In', 'Kaylee', 'F', '1', 'Summers', '360.09751', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', '1.54034E+12', '833', "All Tomorrow's Parties", '200', '1.54329E+12', '8'], ['Snoop Dogg / Jamie Foxx', 'Logged In', 'Kaylee', 'F', '2', 'Summers', '179.35628', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', '1.54034E+12', '833', 'Psst!', '200', '1.54329E+12', '8'], ['Dixie Chicks', 'Logged In', 'Kaylee', 'F', '3', 'Summers', '201.01179', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', '1.54034E+12', '833', "There's Your Trouble", '200', '1.54329E+12', '8'], ['', 'Logged In', 'Kaylee', 'F', '4', 'Summers', '', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'GET', 'Settings', '1.54034E+12', '833', '', '200', '1.54329E+12', '8'], ['Linkin Park', 'Logged In', 'Kaylee', 'F', '5', 'Summers', '189.28281', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'NextSong', '1.54034E+12', '833', 'Given Up (Album Version)', '200', '1.54329E+12', '8'], ['', 'Logged In', 'Kaylee', 'F', '6', 'Summers', '', 'free', 'Phoenix-Mesa-Scottsdale, AZ', 'PUT', 'Logout', '1.54034E+12', '833', '', '307', '1.54329E+12', '8'], ['', 'Logged Out', '', '', '7', '', '', 'free', '', 'GET', 'Home', '', '833', '', '200', '1.54329E+12', ''], ['Alice In Chains', 'Logged In', 'Kevin', 'M', '0', 'Arellano', '239.35955', 'free', 'Harrisburg-Carlisle, PA', 'PUT', 'NextSong', '1.54001E+12', '934', 'Take Her Out', '200', '1.54329E+12', '66'], ['', 'Logged In', 'Anabelle', 'F', '0', 'Simpson', '', 'free', 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', 'GET', 'Home', '1.54104E+12', '926', '', '200', '1.54329E+12', '69'], ['Florence + The Machine', 'Logged In', 'Anabelle', 'F', '1', 'Simpson', '176.69179', 'free', 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', 'PUT', 'NextSong', '1.54104E+12', '926', 'My Boy Builds Coffins', '200', '1.54329E+12', '69'], ['Spoon', 'Logged In', 'Theodore', 'M', '0', 'Smith', '299.20608', 'free', 'Houston-The Woodlands-Sugar Land, TX', 'PUT', 'NextSong', '1.54031E+12', '968', 'The Mystery Zone', '200', '1.5433E+12', '52'], ['', 'Logged In', 'Tucker', 'M', '0', 'Garrison', '', 'free', 'Oxnard-Thousand Oaks-Ventura, CA', 'GET', 'Home', '1.54083E+ ...

# %%
# check the number of rows in your csv file
with open('event_datafile_new.csv', 'r', encoding = 'utf8') as f:
    print(sum(1 for line in f))
# Out:
# 6821

# %% [markdown]
# # Part II. Complete the Apache Cassandra coding portion of your project.
#
# ## Now you are ready to work with the CSV file titled <font color=red>event_datafile_new.csv</font>, located within the Workspace directory.  The event_datafile_new.csv contains the following columns:
# - artist
# - firstName of user
# - gender of user
# - item number in session
# - last name of user
# - length of the song
# - level (paid or free song)
# - location of the user
# - sessionId
# - song title
# - userId
#
# The image below is a screenshot of what the denormalized data should appear like in the <font color=red>**event_datafile_new.csv**</font> after the code above is run:<br>
#
# <img src="images/image_event_datafile_new.jpg">

# %% [markdown]
# ## Begin writing your Apache Cassandra code in the cells below

# %% [markdown]
# #### Creating a Cluster

# %%
# This should make a connection to a Cassandra instance your local machine 
# (127.0.0.1)

from cassandra.cluster import Cluster
cluster = Cluster()

# To establish connection and begin executing queries, need a session
session = cluster.connect()

# %% [markdown]
# #### Create Keyspace

# %%
# TO-DO: Create a Keyspace 
session.execute("""
CREATE KEYSPACE IF NOT EXISTS udacity 
WITH REPLICATION = 
{ 'class' : 'SimpleStrategy', 'replication_factor' : 1 }"""
)

# %% [markdown]
# #### Set Keyspace

# %%
# TO-DO: Set KEYSPACE to the keyspace specified above
session.set_keyspace('udacity')

# %% [markdown]
# ### Now we need to create tables to run the following queries. Remember, with Apache Cassandra you model the database tables on the queries you want to run.

# %% [markdown]
# ## Create queries to ask the following three questions of the data
#
# ### 1. Give me the artist, song title and song's length in the music app history that was heard during  sessionId = 338, and itemInSession  = 4
#
#
# ### 2. Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name) for userid = 10, sessionid = 182
#
#
# ### 3. Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %%
## TO-DO: Query 1:  Give me the artist, song title and song's length in the music app history that was heard during \
## sessionId = 338, and itemInSession = 4

query = "CREATE TABLE IF NOT EXISTS music_events "
query = query + """(artist text, song text, length float, sessionId int, itemInSession int, 
PRIMARY KEY (sessionId, itemInSession))"""
try:
    session.execute(query)
except Exception as e:
    print(e)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
## TO-DO: Assign the INSERT statements into the `query` variable
        query = "INSERT INTO music_events (artist, song, length, sessionId, itemInSession) "
        query = query + " VALUES (%s, %s, %s, %s, %s)"
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (line[0], line[9], float(line[5]), int(line[8]), int(line[3])))
# Out:
# Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner
# Mohammad
# M
# 0
# Rodriguez
# 277.15873
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# 88
# Jimi Hendrix
# Mohammad
# M
# 1
# Rodriguez
# 239.82975
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Woodstock Inprovisation
# 88
# Building 429
# Mohammad
# M
# 2
# Rodriguez
# 300.61669
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Majesty (LP Version)
# 88
# The B-52's
# Gianna
# F
# 0
# Jones
# 321.54077
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Love Shack
# 38
# Die Mooskirchner
# Gianna
# F
# 1
# Jones
# 169.29914
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Frisch und g'sund
# 38
# Carrie Underwood
# Gianna
# F
# 2
# Jones
# 195.70893
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Look At Me
# 38
# No Te Va Gustar
# Kaylee
# F
# 0
# Summers
# 246.43873
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Ya EntendÃÂ­
# 8
# The Velvet Underground / Nico
# Kaylee
# F
# 1
# Summers
# 360.09751
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# All Tomorrow's Parties
# 8
# Snoop Dogg / Jamie Foxx
# Kaylee
# F
# 2
# Summers
# 179.35628
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Psst!
# 8
# Dixie Chicks
# Kaylee
# F
# 3
# Summers
# 201.01179
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# There's Your Trouble
# 8
# Linkin Park
# Kaylee
# F
# 5
# Summers
# 189.28281
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Given Up (Album Version)
# 8
# Alice In Chains
# Kevin
# M
# 0
# Arellano
# 239.35955
# free
# Harrisburg-Carlisle, PA
# <class 'str'>
# Take Her Out
# 66
# Florence + The Machine
# Anabelle
# F
# 1
# Simpson
# 176.69179
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# My Boy Builds Coffins
# 69
# Spoon
# Theodore
# M
# 0
# Smith
# 299.20608
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# The Mystery Zone
# 52
# Alice In Chains
# Aiden
# M
# 1
# Hess
# 223.26812
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# Would?
# 86
# Natalie Walker
# Aiden
# M
# 2
# Hess
# 191.84281
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# Colorblind
# 86
# Traveling Wilburys
# Ava
# F
# 0
# Robinson
# 207.59465
# free
# New Haven-Milford, CT
# <class 'str'>
# End Of The Line
# 50
# Cherokee
# Chloe
# F
# 0
# Cuevas
# 414.6673
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Relax
# 49
# NOFX
# Chloe
# F
# 1
# Cuevas
# 1099.78077
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# The Decline
# 49
# Cameo
# Chloe
# F
# 2
# Cuevas
# 211.98322
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Word Up!
# 49
# Natalia Lafourcade
# Layla
# F
# 0
# Griffin
# 264.25424
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Look Outside
# 24
# J Dilla
# Layla
# F
# 1
# Griffin
# 232.46322
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Won't Do
# 24
# Sergio Mendes
# Layla
# F
# 2
# Griffin
# 254.85016
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Never Gonna Let You Go
# 24
# Jarabe De Palo
# Layla
# F
# 3
# Griffin
# 205.08689
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# En Lo Puro No Hay Futuro
# 24
# Carrie Underwood
# Layla
# F
# 4
# Griffin
# 257.88036
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# I Told You So
# 24
# Enigma
# Elijah
# M
# 0
# Davis
# 258.71628
# free
# Detroit-Warren-Dearborn, MI
# <class 'str'>
# Je T'aime Till My Dying Day
# 5
# Kelly Clarkson
# Layla
# F
# 5
# Griffin
# 221.09995
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# The Trouble With Love Is
# 24
# Timbaland & Magoo
# Layla
# F
# 6
# Griffin
# 279.7971
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Put 'Em On
# 24
# The Wombats
# Elijah
# M
# 1
# Davis
# 69.95546
# free
# Detroit-Warren-Dearborn, MI
# <class 'str'>
# Tales of Girls_ Boys and Marsupials (album version)
# 5
# Andrew Bird
# Elijah
# M
# 2
# Davis
# 316.47302
# free
# Detroit-Warren-Dearborn, MI
# <class 'str'>
# Skin Is_ My
# 5
# Colin James
# Layla
# F
# 8
# Griffin
# 298.52689
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Just Came Back
# 24
# Los Wawanco
# Rylan
# M
# 0
# George
# 165.79873
# paid
# Birmingham-Hoover, AL
# <class 'str'>
# La Casita Blanca
# 16
# Dancing DJ's v Roxette
# Layla
# F
# 9
# Griffin
# 370.78159
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Fading Like A Flower (Extended Mix)
# 24
# Robert Rich & Alio Die
# Layla
# F
# 10
# Griffin
# 375.92771
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# Sirena
# 24
# Gabin featuring China Moses
# Layla
# F
# 11
# Griffin
# 249.36444
# paid
# Lake Havasu City-Kingman, AZ
# <class 'str'>
# The Other Way Round (Feat. China Moses)
# 24
# Los Lobos
# Aiden
# M
# 0
# Hess
# 174.18404
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# La Bamba
# 86
# Robert Pollard
# Aiden
# M
# 1
# Hess
# 202.91873
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# We All Got Out (of the Army)
# 86
# MÃÂ¥ns ZelmerlÃÂ¶w
# Aiden
# M
# 2
# Hess
# 206.96771
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# Brother Oh Brother
# 86
# Shakira
# Aiden
# M
# 3
# Hess
# 192.70485
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# Did it Again
# 86
# Showbread
# Aiden
# M
# 4
# Hess
# 297.58649
# free
# La Crosse-Onalaska, WI-MN
# <class 'str'>
# The Pig
# 86
# DHT Feat. EdmÃÂ©e
# Chloe
# F
# 1
# Cuevas
# 229.98159
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Listen To Your Heart
# 49
# Bersuit Vergarabat
# Chloe
# F
# 2
# Cuevas
# 212.40118
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Yo Tomo
# 49
# La Roux
# Chloe
# F
# 3
# Cuevas
# 185.65179
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Quicksand
# 49
# Conjure One
# Chloe
# F
# 4
# Cuevas
# 300.09424
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Center Of The Sun
# 49
# Graham Colton
# Chloe
# F
# 5
# Cuevas
# 235.10159
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# On Your Side
# 49
# The Starting Line
# Chloe
# F
# 6
# Cuevas
# 207.85587
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# I'm Real
# 49
# Jimmy Eat World
# Chloe
# F
# 7
# Cuevas
# 385.802
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Drugs Or Me
# 49
# Pull Tiger Tail
# Chloe
# F
# 8
# Cuevas
# 239.882
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Hurricanes
# 49
# OneRepublic
# Chloe
# F
# 9
# Cuevas
# 224.67873
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Secrets
# 49
# Hannah Montana
# Chloe
# F
# 10
# Cuevas
# 174.00118
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# The Best Of Both Worlds
# 49
# Ramses Shaffy
# Matthew
# M
# 1
# Jones
# 332.69506
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Laat Me.
# 36
# Van Halen
# Matthew
# M
# 2
# Jones
# 228.33587
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Why Can't This Be Love (Remastered Version)
# 36
# Method Man
# Ava
# F
# 0
# Robinson
# 195.97016
# free
# New Haven-Milford, CT
# <class 'str'>
# All I Need
# 50
# Mando Diao
# Matthew
# M
# 3
# Jones
# 238.54975
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Down In The Past
# 36
# The Archies
# Ava
# F
# 1
# Robinson
# 166.16444
# free
# New Haven-Milford, CT
# <class 'str'>
# Sugar Sugar
# 50
# OneRepublic
# Matthew
# M
# 4
# Jones
# 208.14322
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Apologize
# 36
# Ensiferum
# Matthew
# M
# 5
# Jones
# 273.8673
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Lady In Black
# 36
# Gold Panda
# Matthew
# M
# 6
# Jones
# 189.09995
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Win-san Western
# 36
# Dixie Chicks
# Matthew
# M
# 7
# Jones
# 206.44526
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Tonight The Heartache's On Me
# 36
# Ferry Corsten
# Matthew
# M
# 8
# Jones
# 466.46812
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Sublime
# 36
# Energy 52
# Ryan
# M
# 0
# Smith
# 462.13179
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# CafÃÂ© Del Mar
# 26
# Babyshambles
# Matthew
# M
# 9
# Jones
# 206.49751
# paid
# Janesville-Beloit, WI
# <class 'str'>
#
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Greece 2000
# 36
# Eminem
# Chloe
# F
# 10
# Cuevas
# 283.55873
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Deja Vu
# 49
# Creedence Clearwater Revival
# Matthew
# M
# 26
# Jones
# 230.94812
# paid
# Janesville-Beloit, WI
# <class 'str'>
# It's Just A Thought
# 36
# Florence + The Machine
# Chloe
# F
# 11
# Cuevas
# 219.66322
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Dog Days Are Over (Radio Edit)
# 49
# The Kooks
# Matthew
# M
# 27
# Jones
# 98.16771
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Seaside
# 36
# Yazoo
# Matthew
# M
# 28
# Jones
# 178.99057
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Don't Go (Live)
# 36
# Hans Zimmer_ James Newton Howard
# Chloe
# F
# 12
# Cuevas
# 455.47057
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Macrotus
# 49
# Paul Cardall
# Matthew
# M
# 29
# Jones
# 222.87628
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Scarborough Fair
# 36
# Aretha Franklin
# Matthew
# M
# 30
# Jones
# 183.90159
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Hello Sunshine
# 36
# Muse
# Chloe
# F
# 13
# Cuevas
# 209.50159
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Supermassive Black Hole (Twilight Soundtrack Version)
# 49
# Coldplay
# Matthew
# M
# 31
# Jones
# 298.762
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Shiver
# 36
# Eric Clapton
# Chloe
# F
# 14
# Cuevas
# 271.80363
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Tears In Heaven
# 49
# Kate Winslet
# Matthew
# M
# 37
# Jones
# 106.73587
# paid
# Janesville-Beloit, WI
# <class 'str'>
# What If (Film Version)
# 36
# Roadrunner United
# Chloe
# F
# 15
# Cuevas
# 285.02159
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# The Enemy (Album Version)
# 49
# Flogging Molly
# Matthew
# M
# 38
# Jones
# 260.75383
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Punch Drunk Grinning Soul
# 36
# Apocalyptica
# Chloe
# F
# 16
# Cuevas
# 206.15791
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Quutamo
# 49
# Blind Melon
# Matthew
# M
# 39
# Jones
# 214.72608
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Mouthful Of Cavities
# 36
# Killswitch Engage
# Chloe
# F
# 17
# Cuevas
# 254.45832
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# In A Dead World (Album Version)
# 49
# Charlie Wilson featuring Snoop Dogg
# Matthew
# M
# 40
# Jones
# 231.70567
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Let It Out
# 36
# Black Eyed Peas
# Chloe
# F
# 18
# Cuevas
# 229.61587
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Let's Get It Started
# 49
# Coldplay
# Matthew
# M
# 41
# Jones
# 139.12771
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Don't Panic
# 36
# Tori Amos Featuring Damien Rice
# Matthew
# M
# 42
# Jones
# 215.82322
# paid
# Janesville-Beloit, WI
# <class 'str'>
# The Power of Orange Knickers
# 36
# Abba
# Matthew
# M
# 43
# Jones
# 213.05424
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Summer Night City
# 36
# Blu Cantrell Featuring Foxy Brown
# Matthew
# M
# 44
# Jones
# 250.69669
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Hit 'Em Up Style (Oops!)
# 36
# Keyshia Cole / T.I. / Missy Elliott / Young Dro
# Matthew
# M
# 45
# Jones
# 220.08118
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Let It Go
# 36
# Maroon 5
# Matthew
# M
# 46
# Jones
# 152.842
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Can't Stop
# 36
# Angels and Airwaves
# Matthew
# M
# 47
# Jones
# 302.05342
# paid
# Janesville-Beloit, WI
# <class 'str'>
# The Gift
# 36
# Silversun Pickups
# Matthew
# M
# 48
# Jones
# 348.23791
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Lazy Eye [Jason Bentley Remix]
# 36
# 65daysofstatic
# Mohammad
# M
# 0
# Rodriguez
# 264.98567
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Drove Through Ghosts to Get Here
# 88
# Los Abuelos De La Nada
# Matthew
# M
# 51
# Jones
# 122.27873
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Se Me OlvidÃÂ³ Que Te OlvidÃÂ©
# 36
# STRATOVARIUS
# Matthew
# M
# 52
# Jones
# 442.06975
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Soul Of A Vagabond
# 36
# Young Money featuring Lloyd
# Mohammad
# M
# 1
# Rodriguez
# 196.33587
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# BedRock (Radio Edit) (feat.Lloyd)
# 88
# The Human League
# Mohammad
# M
# 2
# Rodriguez
# 225.17506
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# (Keep Feeling) Fascination (2003 Digital Remaster)
# 88
# Enya
# Matthew
# M
# 53
# Jones
# 185.7824
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Aldebaran
# 36
# Alceu ValenÃÂ§a
# Mohammad
# M
# 3
# Rodriguez
# 176.56118
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Eu Te Amo
# 88
# Nickel Creek
# Matthew
# M
# 54
# Jones
# 225.69751
# paid
# Janesville-Beloit, WI
# <class 'str'>
# In The House Of Tom Bombadil
# 36
# Linkin Park
# Brantley
# M
# 1
# West
# 208.95302
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# Crawling (Album Version)
# 28
# Matisyahu
# Mohammad
# M
# 4
# Rodriguez
# 222.37995
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# King Without A Crown
# 88
# Bryn Terfel / Berliner Philharmoniker / Claudio Abbado
# Matthew
# M
# 55
# Jones
# 967.36608
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Wotan's Farewell & Magic Fire Music
# 36
# Jens Lekman
# Mohammad
# M
# 5
# Rodriguez
# 210.46812
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Someone To Share My Life With
# 88
# Propellerheads
# Mohammad
# M
# 6
# Rodriguez
# 239.3073
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Take California
# 88
# Daft Punk
# Tegan
# F
# 0
# Levine
# 286.6673
# paid
# Portland-South Portland, ME
# <class 'str'>
# Human After All (SebastiAn Remix )
# 80
# Edward Sharpe & The Magnetic Zeros
# Mohammad
# M
# 7
# Rodriguez
# 306.31138
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Home
# 88
# The Feeling
# Tegan
# F
# 1
# Levine
# 227.36934
# paid
# Portland-South Portland, ME
# <class 'str'>
# I Want You Now
# 80
# Crystal Castles
# Mohammad
# M
# 8
# Rodriguez
# 186.38322
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Untrust us
# 88
# The Black Keys
# Tegan
# F
# 2
# Levine
# 152.52853
# paid
# Portland-South Portland, ME
# <class 'str'>
# Busted
# 80
# Timbaland / Keri Hilson / D.O.E.
# Matthew
# M
# 56
# Jones
# 179.25179
# paid
# Janesville-Beloit, WI
# <class 'str'>
# The Way I Are
# 36
# Oliver Koletzki
# Mohammad
# M
# 9
# Rodriguez
# 609.48853
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Nascita Of The Monsters
# 88
# Josh Groban
# Tegan
# F
# 3
# Levine
# 152.0322
# paid
# Portland-South Portland, ME
# <class 'str'>
# Lullaby [With Ladysmith Black Mambazo] (Album Version)
# 80
# Moonspell
# Matthew
# M
# 57
# Jones
# 293.642
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Hers is the twilight
# 36
# Alliance Ethnik
# Tegan
# F
# 4
# Levine
# 252.21179
# paid
# Portland-South Portland, ME
# <class 'str'>
# ReprÃÂ©sente
# 80
# Silverchair
# Tegan
# F
# 5
# Levine
# 267.88526
# paid
# Portland-South Portland, ME
# <class 'str'>
# Tomorrow
# 80
# Blood Red Shoes
# Matthew
# M
# 58
# Jones
# 186.90567
# paid
# Janesville-Beloit, WI
# <class 'str'>
#
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Him
# 36
# Framing Hanley
# Magdalene
# F
# 2
# Herman
# 230.08608
# free
# Dallas-Fort Worth-Arlington, TX
# <class 'str'>
# Alone In This Bed (Capeside)
# 77
# Andrew Jackson Jihad
# Matthew
# M
# 68
# Jones
# 74.97098
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Brave as a Noun
# 36
# Twista
# Tegan
# F
# 12
# Levine
# 223.03302
# paid
# Portland-South Portland, ME
# <class 'str'>
# Girl Tonite [Featuring Trey Songz] [Explicit Album Version]
# 80
# Sisqo
# Mohammad
# M
# 19
# Rodriguez
# 253.49179
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Thong Song
# 88
# Underworld
# Magdalene
# F
# 3
# Herman
# 158.4322
# free
# Dallas-Fort Worth-Arlington, TX
# <class 'str'>
# To Heal
# 77
# Paramore
# Matthew
# M
# 69
# Jones
# 267.65016
# paid
# Janesville-Beloit, WI
# <class 'str'>
# The Only Exception (Album Version)
# 36
# Train
# Magdalene
# F
# 4
# Herman
# 216.76363
# free
# Dallas-Fort Worth-Arlington, TX
# <class 'str'>
# Hey_ Soul Sister
# 77
# Die Mooskirchner
# Tegan
# F
# 13
# Levine
# 169.29914
# paid
# Portland-South Portland, ME
# <class 'str'>
# Frisch und g'sund
# 80
# Ron Carter
# Mohammad
# M
# 20
# Rodriguez
# 497.13587
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# I CAN'T GET STARTED
# 88
# Bo Kaspers Orkester
# Matthew
# M
# 70
# Jones
# 259.36934
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Undantag
# 36
# Kid Cudi / MGMT / Ratatat
# Magdalene
# F
# 5
# Herman
# 295.67955
# free
# Dallas-Fort Worth-Arlington, TX
# <class 'str'>
# Pursuit Of Happiness (nightmare)
# 77
# Bacilos
# Matthew
# M
# 71
# Jones
# 307.51302
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Viejo
# 36
# Alejandro Sanz
# Mohammad
# M
# 21
# Rodriguez
# 277.2371
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Y solo se me ocurre amarte (Unplugged)
# 88
# UNKLE
# Matthew
# M
# 73
# Jones
# 295.54893
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Burn My Shadow
# 36
# the bird and the bee
# Mohammad
# M
# 22
# Rodriguez
# 225.17506
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# My Love
# 88
# TRUSTcompany
# Martin
# M
# 0
# Johnson
# 194.2722
# free
# Minneapolis-St. Paul-Bloomington, MN-WI
# <class 'str'>
# Take It All
# 55
# Pixies
# Matthew
# M
# 74
# Jones
# 229.3024
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Where Is My Mind?
# 36
# Faith No More
# Mohammad
# M
# 23
# Rodriguez
# 249.86077
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# Last Cup Of Sorrow
# 88
# Big Tymers
# Matthew
# M
# 75
# Jones
# 289.95873
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Rocky
# 36
# The Darkness
# Mohammad
# M
# 24
# Rodriguez
# 217.05098
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# I Believe In A Thing Called Love
# 88
# D Black
# Matthew
# M
# 76
# Jones
# 261.14567
# paid
# Janesville-Beloit, WI
# <class 'str'>
# Mais E Mais Amor
# 36
# Craig Mack
# Mohammad
# M
# 25
# Rodriguez
# 218.04363
# paid
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
#
# <class 'str'>
# Love & Leaving
# 61
# Pet Shop Boys With Dusty Springfield
# Tegan
# F
# 45
# Levine
# 262.19057
# paid
# Portland-South Portland, ME
# <class 'str'>
# What Have I Done To Deserve This? (2001 Digital Remaster)
# 80
# Paramore
# Samuel
# M
# 3
# Gonzalez
# 267.65016
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# The Only Exception (Album Version)
# 61
# The Offspring
# Tegan
# F
# 46
# Levine
# 239.93424
# paid
# Portland-South Portland, ME
# <class 'str'>
# We Are One
# 80
# Markus Schulz Feat. Departure
# Samuel
# M
# 6
# Gonzalez
# 543.58159
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Cause You Know
# 61
# Lupe Fiasco feat. Nikki Jean
# Tegan
# F
# 47
# Levine
# 242.49424
# paid
# Portland-South Portland, ME
# <class 'str'>
# Hip-Hop Saved My Life (feat. Nikki Jean) (Explicit Album Version)
# 80
# ISRAEL & NEW BREED
# Tegan
# F
# 48
# Levine
# 469.52444
# paid
# Portland-South Portland, ME
# <class 'str'>
# If Not For Your Grace
# 80
# Florence + The Machine
# Samuel
# M
# 7
# Gonzalez
# 80.87465
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Bird Song Intro
# 61
# Crash Romeo
# Tegan
# F
# 49
# Levine
# 170.84036
# paid
# Portland-South Portland, ME
# <class 'str'>
# Actions not words
# 80
# Royksopp
# Tegan
# F
# 50
# Levine
# 163.65669
# paid
# Portland-South Portland, ME
# <class 'str'>
# Happy Up Here
# 80
# Cage The Elephant
# Tegan
# F
# 51
# Levine
# 241.162
# paid
# Portland-South Portland, ME
# <class 'str'>
# In One Ear
# 80
# The Unwinding Hours
# Tegan
# F
# 52
# Levine
# 301.50485
# paid
# Portland-South Portland, ME
# <class 'str'>
# There Are Worse Things Than Being Alone
# 80
# Shakira
# Tegan
# F
# 53
# Levine
# 159.05914
# paid
# Portland-South Portland, ME
# <class 'str'>
# La Pared
# 80
# Vader
# Tegan
# F
# 54
# Levine
# 245.86404
# paid
# Portland-South Portland, ME
# <class 'str'>
# Fight Fire With Fire
# 80
# Combichrist
# Lily
# F
# 0
# Burns
# 336.14322
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# red signal
# 32
# Good Old War
# Tegan
# F
# 55
# Levine
# 166.03383
# paid
# Portland-South Portland, ME
# <class 'str'>
# Just Another Day
# 80
# Regina Spektor
# Tegan
# F
# 56
# Levine
# 122.43546
# paid
# Portland-South Portland, ME
# <class 'str'>
# Baobabs (Bonus Album Version)
# 80
# Cartola
# Tegan
# F
# 57
# Levine
# 208.92689
# paid
# Portland-South Portland, ME
# <class 'str'>
# Sala De RecepÃÂ§ÃÂ£o
# 80
# The Offspring
# Tegan
# F
# 58
# Levine
# 175.04608
# paid
# Portland-South Portland, ME
# <class 'str'>
# Not the One (Album Version)
# 80
# Nirvana
# Tegan
# F
# 59
# Levine
# 257.01832
# paid
# Portland-South Portland, ME
# <class 'str'>
# Lithium
# 80
# The Radio Dept.
# Tegan
# F
# 60
# Levine
# 163.36934
# paid
# Portland-South Portland, ME
# <class 'str'>
# Where Damage Isn't Already Done
# 80
# OlÃÂ© OlÃÂ©
# Tegan
# F
# 61
# Levine
# 247.87546
# paid
# Portland-South Portland, ME
# <class 'str'>
# Con sÃÂ³lo una mirada
# 80
# Lady GaGa
# Tegan
# F
# 62
# Levine
# 274.18077
# paid
# Portland-South Portland, ME
# <class 'str'>
# Alejandro
# 80
# The Temper Trap
# Tegan
# F
# 63
# Levine
# 275.40853
# paid
# Portland-South Portland, ME
# <class 'str'>
# Fools
# 80
# The Avett Brothers
# Tegan
# F
# 64
# Levine
# 244.29669
# paid
# Portland-South Portland, ME
# <class 'str'>
# Go To Sleep
# 80
# Professor Longhair
# Ann
# F
# 0
# Banks
# 214.20363
# free
# Salt Lake City, UT
# <class 'str'>
# Mean Ol'World
# 99
# Gary Hobbs
# Jahiem
# M
# 1
# Miles
# 245.52444
# free
# San Antonio-New Braunfels, TX
# <class 'str'>
# En Mi Mundo
# 43
# Lifehouse
# Jahiem
# M
# 2
# Miles
# 203.59791
# free
# San Antonio-New Braunfels, TX
# <class 'str'>
# We'll Never Know
# 43
# Olivia Ruiz
# Jahiem
# M
# 3
# Miles
# 254.74567
# free
# San Antonio-New Braunfels, TX
# <class 'str'>
# Cabaret Blanco
# 43
# Jordan Rudess
# Cecilia
# F
# 1
# Owens
# 1367.84934
# free
# Atlanta-Sandy Springs-Roswell, GA
# <class 'str'>
# Tarkus
# 6
# Deerhunter
# Jayden
# M
# 0
# Graves
# 162.08934
# paid
# Marinette, WI-MI
# <class 'str'>
# Weird Era
# 25
# Daughtry
# Jayden
# M
# 1
# Graves
# 249.91302
# paid
# Marinette, WI-MI
# <class 'str'>
# No Surprise
# 25
# Vinylshakerz
# Jayden
# M
# 6
# Graves
# 207.25506
# paid
# Marinette, WI-MI
# <class 'str'>
# Club Tropicana
# 25
# Barry Tuckwell/Academy of St Martin-in-the-Fields/Sir Neville Marriner
# Jayden
# M
# 7
# Graves
# 277.15873
# paid
# Marinette, WI-MI
# <class 'str'>
# Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)
# 25
# Son House
# Jayden
# M
# 8
# Graves
# 182.43873
# paid
# Marinette, WI-MI
# <class 'str'>
# Depot Blues
# 25
# Jason Mraz & Colbie Caillat
# Jayden
# M
# 9
# Graves
# 189.6224
# paid
# Marinette, WI-MI
# <class 'str'>
# Lucky (Album Version)
# 25
# The Romantics
# Jayden
# M
# 10
# Graves
# 233.7171
# paid
# Marinette, WI-MI
# <class 'str'>
# Talking In Your Sleep
# 25
# The Postal Service
# Jayden
# M
# 11
# Graves
# 266.47465
# paid
# Marinette, WI-MI
# <class 'str'>
# Such Great Heights
# 25
# Tweet
# Jayden
# M
# 12
# Graves
# 281.80853
# paid
# Marinette, WI-MI
# <class 'str'>
# Always Will (LP Version)
# 25
# Gang Starr/Inspectah Deck
# Jayden
# M
# 13
# Graves
# 225.07057
# paid
# Marinette, WI-MI
# <class 'str'>
# Above The Clouds (Edited)
# 25
# Kanye West
# Jayden
# M
# 14
# Graves
# 164.38812
# paid
# Marinette, WI-MI
# <class 'str'>
# Coldest Winter
# 25
# Shunza
# Jayden
# M
# 15
# Graves
# 250.93179
# paid
# Marinette, WI-MI
# <class 'str'>
# Nan Ni Wan
# 25
# Erykah Badu
# Jayden
# M
# 16
# Graves
# 286.9024
# paid
# Marinette, WI-MI
# <class 'str'>
# Back In The Day
# 25
# Mariza
# Maia
# F
# 0
# Burke
# 239.3073
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Vielas De Alfama
# 51
# Asia 2001
# Jayden
# M
# 22
# Graves
# 150.30812
# paid
# Marinette, WI-MI
# <class 'str'>
# Epilogue
# 25
# Alejandro Sanz
# Maia
# F
# 1
# Burke
# 230.24281
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Non E_ Per Te_ Per Me
# 51
# The Casualties
# Jayden
# M
# 23
# Graves
# 131.23873
# paid
# Marinette, WI-MI
# <class 'str'>
# Fight For Your Life
# 25
# Alliance Ethnik
# Jayden
# M
# 24
# Graves
# 252.21179
# paid
# Marinette, WI-MI
# <class 'str'>
# ReprÃÂ©sente
# 25
# Hey Monday
# Jayden
# M
# 25
# Graves
# 222.98077
# paid
# Marinette, WI-MI
# <class 'str'>
# Run_ Don't Walk
# 25
# Silverchair
# Jayden
# M
# 26
# Graves
# 213.13261
# paid
# Marinette, WI-MI
# <class 'str'>
# The Door
# 25
# El DeBarge
# Jayden
# M
# 27
# Graves
# 323.47383
# paid
# Marinette, WI-MI
# <class 'str'>
# Love Always
# 25
# Evanescence
# Jayden
# M
# 28
# Graves
# 236.12036
# paid
# Marinette, WI-MI
# <class 'str'>
# Bring Me To Life
# 25
# Ludovico Einaudi
# Jayden
# M
# 30
# Graves
# 249.02485
# paid
# Marinette, WI-MI
# <class 'str'>
# The Snow Prelude No. 2
# 25
# Caifanes
# Jayden
# M
# 31
# Graves
# 210.88608
# paid
# Marinette, WI-MI
# <class 'str'>
# Ayer Me Dijo Un Ave
# 25
# The xx
# Jayden
# M
# 32
# Graves
# 188.55138
# paid
# Marinette, WI-MI
# <class 'str'>
# Basic Space
# 25
# Swizz Beatz
# Jayden
# M
# 33
# Graves
# 213.7073
# paid
# Marinette, WI-MI
# <class 'str'>
# Big Munny
# 25
# OutKast
# Jayden
# M
# 34
# Graves
# 239.35955
# paid
# Marinette, WI-MI
# <class 'str'>
# Ms. Jackson
# 25
# The Black Keys
# Jayden
# M
# 35
# Graves
# 300.30322
# paid
# Marinette, WI-MI
# <class 'str'>
# The Only One
# 25
# Nappy Roots [featuring Anthony Hamilton]
# Jayden
# M
# 36
# Graves
# 248.00608
# paid
# Marinette, WI-MI
# <class 'str'>
# Po' Folks
# 25
# Whitesnake
# Jayden
# M
# 37
# Graves
# 250.3571
# paid
# Marinette, WI-MI
# <class 'str'>
# Fool For Your Loving
# 25
# Foolish Things
# Jayden
# M
# 38
# Graves
# 266.86649
# paid
# Marinette, WI-MI
# <class 'str'>
# Who Can Compare
# 25
# Soda Stereo
# Jayden
# M
# 39
# Graves
# 317.6224
# paid
# Marinette, WI-MI
# <class 'str'>
# PrÃÂ³fugos
# 25
# Edward Sharpe & The Magnetic Zeros
# Jayden
# M
# 40
# Graves
# 306.31138
# paid
# Marinette, WI-MI
# <class 'str'>
# Home
# 25
# Anberlin
# Aleena
# F
# 0
# Kirby
# 258.42893
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Dismantle. Repair.
# 44
# L-7
# Aleena
# F
# 2
# Kirby
# 168.56771
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Shitlist
# 44
# Future Of The Left
# Aleena
# F
# 4
# Kirby
# 112.63955
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Fingers Become Thumbs
# 44
# Franz Ferdinand
# Aleena
# F
# 5
# Kirby
# 206.28853
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Call Me
# 44
# Travie McCoy
# Aleena
# F
# 6
# Kirby
# 211.12118
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Billionaire [feat. Bruno Mars]  (Explicit Album Version)
# 44
# Lily Allen
# Aleena
# F
# 7
# Kirby
# 194.76853
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Smile
# 44
# Rancid
# Aleena
# F
# 8
# Kirby
# 223.65995
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Fall Back Down (Album Version)
# 44
# Katy Perry
# Aleena
# F
# 9
# Kirby
# 228.49261
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# I'm Still Breathing
# 44
# Freestylers
# Aleena
# F
# 10
# Kirby
# 340.06159
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Punks (Krafty Kuts Remix)
# 44
# Kid Rock
# Rylan
# M
# 1
# George
# 296.95955
# free
# Birmingham-Hoover, AL
# <class 'str'>
# All Summer Long (Album Version)
# 16
# LITE
# Aleena
# F
# 11
# Kirby
# 248.08444
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# On A Gloomy Evening
# 44
# The Killers
# Rylan
# M
# 2
# George
# 220.89098
# free
# Birmingham-Hoover, AL
# <class 'str'>
# When You Were Young
# 16
# Hymie's Basement
# Aleena
# F
# 12
# Kirby
# 175.38567
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Ghost Dream
# 44
# Pavement
# Aleena
# F
# 13
# Kirby
# 195.73506
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Rooftop Gambler
# 44
# Trey Songz
# Rylan
# M
# 3
# George
# 205.81832
# free
# Birmingham-Hoover, AL
# <class 'str'>
# Can't Help But Wait (Album Version)
# 16
# Shakira
# Aleena
# F
# 14
# Kirby
# 159.05914
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# La Pared
# 44
# Billy J Kramer & The Dakotas
# Rylan
# M
# 4
# George
# 191.32036
# free
# Birmingham-Hoover, AL
# <class 'str'>
# Tennessee Waltz (Live)
# 16
# Arctic Monkeys
# Aleena
# F
# 15
# Kirby
# 138.10893
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# D is for Dangerous
# 44
# Dashboard Confessional
# Rylan
# M
# 5
# George
# 224.54812
# free
# Birmingham-Hoover, AL
# <class 'str'>
# Ghost Of A Good Thing
# 16
# Moby
# Aleena
# F
# 18
# Kirby
# 196.75383
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Lift Me Up
# 44
# Dan Deacon
# Aleena
# F
# 19
# Kirby
# 483.89179
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Snookered
# 44
# Puddle Of Mudd
# Aleena
# F
# 20
# Kirby
# 210.80771
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Psycho
# 44
# Red Hot Chili Peppers
# Aleena
# F
# 21
# Kirby
# 334.65424
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Snow [Hey Oh] (Album Version)
# 44
# The Barbarians
# Aleena
# F
# 22
# Kirby
# 149.44608
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Memphis_ Tennessee
# 44
# Julia Fordham
# Aleena
# F
# 23
# Kirby
# 213.44608
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Jump (Live)
# 44
# Alicia Keys
# Aleena
# F
# 24
# Kirby
# 455.52281
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Streets Of New York (City Life)
# 44
# Regina Spektor
# Aleena
# F
# 25
# Kirby
# 247.69261
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Another Town
# 44
# Deborah Harry & Iggy Pop
# Aleena
# F
# 26
# Kirby
# 207.49016
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Well Did You Evah!
# 44
# Dr. Dre / Eminem / Alvin Joiner
# Aleena
# F
# 27
# Kirby
# 244.21832
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# What's The Difference
# 44
# Marcel Woods
# Aleena
# F
# 28
# Kirby
# 424.33261
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Advanced (Ton T.B. Mix)
# 44
# OneRepublic
# Aleena
# F
# 29
# Kirby
# 208.14322
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Apologize
# 44
# Beastie Boys
# Aleena
# F
# 30
# Kirby
# 172.22485
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# The Maestro
# 44
# Paramore
# Aleena
# F
# 31
# Kirby
# 267.65016
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# The Only Exception (Album Version)
# 44
# Varios
# Aleena
# F
# 32
# Kirby
# 204.64281
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Hasta siempre
# 44
# The Black Keys
# Aleena
# F
# 33
# Kirby
# 191.76444
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Howlin For You
# 44
# Muse
# Aleena
# F
# 34
# Kirby
# 198.79138
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Feeling Good
# 44
# Frankie J
# Aleena
# F
# 35
# Kirby
# 254.32771
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Daddy's Little Girl
# 44
# Kirk Franklin & The Family
# Aleena
# F
# 36
# Kirby
# 418.71628
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Now Behold The Lamb
# 44
# Cooly's Hot Box
# Aleena
# F
# 37
# Kirby
# 371.06893
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Make Me Happy
# 44
# Ron Van Den Beuken
# Cecilia
# F
# 0
# Owens
# 506.5922
# free
# Atlanta-Sandy Springs-Roswell, GA
# <class 'str'>
# Timeless
# 6
# Sparks
# Aleena
# F
# 38
# Kirby
# 199.02649
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Lost And Found
# 44
# Regina Spektor
# Aleena
# F
# 39
# Kirby
# 191.08526
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# The Calculation (Album Version)
# 44
# Subhumans
# Aleena
# F
# 40
# Kirby
# 209.37098
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Rain
# 44
# Sia
# Aleena
# F
# 43
# Kirby
# 302.602
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Beautiful Calm Driving
# 44
# Shadows Fall
# Aleena
# F
# 44
# Kirby
# 178.65098
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Lead Me Home
# 44
# Eminem / Dr. Dre / 50 Cent
# Aleena
# F
# 45
# Kirby
# 297.56036
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Crack A Bottle
# 44
# Vampire Weekend
# Aleena
# F
# 46
# Kirby
# 195.7873
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Oxford Comma (Album)
# 44
# Eddie Floyd
# Lily
# F
# 1
# Burns
# 198.19057
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Guess Who
# 32
# The Swell Season
# Sylvie
# F
# 0
# Cruz
# 319.13751
# free
# Washington-Arlington-Alexandria, DC-VA-MD-WV
# <class 'str'>
# If You Want Me (Live)
# 10
# Alex Band
# Jordan
# F
# 0
# Hicks
# 238.8371
# free
# Salinas, CA
# <class 'str'>
# Tonight (Single Mix)
# 37
# Nightwish
# Sylvie
# F
# 1
# Cruz
# 305.97179
# free
# Washington-Arlington-Alexandria, DC-VA-MD-WV
# <class 'str'>
# The Islander
# 10
# Cartola
# Brantley
# M
# 0
# West
# 172.12036
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# As Rosas NÃÂ£o Falam
# 28
# Vampire Weekend
# Brantley
# M
# 1
# West
# 269.16526
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# I Think Ur A Contra
# 28
# Sebadoh
# Brantley
# M
# 2
# West
# 210.18077
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# Hassle
# 28
# Incubus
# Brantley
# M
# 3
# West
# 212.74077
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# Wish You Were Here
# 28
# Blue States
# Brantley
# M
# 4
# West
# 239.3073
# free
# Portland-Vancouver-Hillsboro, OR-WA
# <class 'str'>
# Allies
# 28
# Octopus Project
# Magdalene
# F
# 1
# Herman
# 498.33751
# free
# Dallas-Fort Worth-Arlington, TX
# <class 'str'>
# Hypnopaedia
# 77
# Mike Posner
# Jahiem
# M
# 0
# Miles
# 214.7522
# free
# San Antonio-New Braunfels, TX
# <class 'str'>
# Cooler Than Me
# 43
# Alliance Ethnik
# Chloe
# F
# 0
# Roth
# 252.21179
# free
# Indianapolis-Carmel-Anderson, IN
# <class 'str'>
# ReprÃÂ©sente
# 78
# Gang Starr/Inspectah Deck
# Chloe
# F
# 3
# Roth
# 225.07057
# free
# Indianapolis-Carmel-Anderson, IN
# <class 'str'>
# Above The Clouds (Edited)
# 78
# Was (Not Was)
# Braden
# M
# 1
# Parker
# 239.15057
# free
# Youngstown-Warren-Boardman, OH-PA
# <class 'str'>
# Shake Your Head
# 74
# 23 Skidoo
# Chloe
# F
# 4
# Roth
# 370.88608
# free
# Indianapolis-Carmel-Anderson, IN
# <class 'str'>
# Crossfire
# 78
# Dwight Yoakam
# Chloe
# F
# 5
# Roth
# 239.3073
# free
# Indianapolis-Carmel-Anderson, IN
# <class 'str'>
# You're The One
# 78
# Finger Eleven
# Adler
# M
# 1
# Barrera
# 259.68281
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Obvious Heart
# 100
# Shaggy
# Adler
# M
# 2
# Barrera
# 212.97587
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Intoxication
# 100
# Kid Cudi
# Anabelle
# F
# 0
# Simpson
# 227.34322
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# Up Up & Away
# 69
# Klaus Doldinger's Passport
# Adler
# M
# 3
# Barrera
# 460.43383
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Fairy Tale
# 100
# Aesop Rock
# Anabelle
# F
# 1
# Simpson
# 245.65506
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# None Shall Pass (Main)
# 69
# Salt 'n' Pepa with En Vogue
# Bronson
# M
# 0
# Harris
# 296.202
# free
# Eugene, OR
# <class 'str'>
# Whatta Man (Salt-N-Pepa Featuring En Vogue) (EP Version)
# 33
# Tiger Army
# Bronson
# M
# 1
# Harris
# 129.38404
# free
# Eugene, OR
# <class 'str'>
# Ghost Tigers Rise (Album Version)
# 33
# NEEDTOBREATHE
# Bronson
# M
# 2
# Harris
# 225.82812
# free
# Eugene, OR
# <class 'str'>
# Don't Wait For Daylight (Album Version)
# 33
# Baby Huey & The Baby Sitters
# Tegan
# F
# 0
# Levine
# 194.7424
# free
# Portland-South Portland, ME
# <class 'str'>
# Hard Times (LP Version)
# 80
# Justin Bieber
# Tegan
# F
# 1
# Levine
# 220.89098
# free
# Portland-South Portland, ME
# <class 'str'>
# Somebody To Love
# 80
# David Byrne & Fatboy Slim feat. Charmaine Clamor
# Tegan
# F
# 2
# Levine
# 238.65424
# free
# Portland-South Portland, ME
# <class 'str'>
# Walk Like A Woman (Album Version)
# 80
# Taylor Swift
# Tegan
# F
# 3
# Levine
# 230.47791
# free
# Portland-South Portland, ME
# <class 'str'>
# You Belong With Me
# 80
# Ottmar Liebert
# Tegan
# F
# 4
# Levine
# 174.54975
# free
# Portland-South Portland, ME
# <class 'str'>
# Festival (Of 7 Lights)
# 80
# The Roots
# Jacob
# M
# 0
# Klein
# 285.6224
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Dynamite!
# 73
# Foo Fighters
# Jacob
# M
# 1
# Klein
# 235.28444
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Learn To Fly
# 73
# El Hombre Burbuja
# Jacob
# M
# 2
# Klein
# 161.33179
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Buzos (En La Luna)
# 73
# Rock Kills Kid
# Jacob
# M
# 3
# Klein
# 271.38567
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Back To Life (Album Version)
# 73
# Manu Chao
# Jacob
# M
# 4
# Klein
# 288.15628
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Me Quedo Contigo [Si Me Das A Elegir]
# 73
# B.o.B
# Jacob
# M
# 5
# Klein
# 269.63546
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Nothin' On You [feat. Bruno Mars] (Album Version)
# 73
# Baby Boy Da Prince / Mannie Fresh
# Jacob
# M
# 6
# Klein
# 235.2322
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Naw Meen
# 73
# Gerry Rafferty
# Jacob
# M
# 7
# Klein
# 224.39138
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Don't Close The Door
# 73
# the bird and the bee
# Jacob
# M
# 10
# Klein
# 165.642
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Again & Again
# 73
# Blur
# Jacob
# M
# 11
# Klein
# 361.58649
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Sing
# 73
# Puerto Rican Power
# Jacob
# M
# 12
# Klein
# 305.44934
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Juguete De Nadie
# 73
# Hercules And Love Affair
# Jacob
# M
# 13
# Klein
# 471.74485
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Blind (Frankie Knuckles Remix)
# 73
# BeyoncÃÂ©
# Jacob
# M
# 14
# Klein
# 235.67628
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Kitty Kat
# 73
# Burt Bacharach
# Jacob
# M
# 15
# Klein
# 200.54159
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Pacific Coast Highway
# 73
# Common
# Jacob
# M
# 16
# Klein
# 144.16934
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Be (Intro)
# 73
# Ra Ra Riot
# Jacob
# M
# 17
# Klein
# 152.71138
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Can You Tell
# 73
# Flyleaf
# Jacob
# M
# 18
# Klein
# 167.8624
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# There For You
# 73
# Neil Young
# Jacob
# M
# 19
# Klein
# 414.69342
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Danger Bird (Album Version)
# 73
# A Day To Remember
# Jacob
# M
# 20
# Klein
# 87.50975
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Don't You Know Who I Think I Am?
# 97
# Lonnie Gordon
# Kate
# F
# 99
# Harrell
# 181.21098
# paid
# Lansing-East Lansing, MI
# <class 'str'>
# Catch You Baby (Steve Pitron & Max Sanna Radio Edit)
# 97
# Crystal Castles
# Kate
# F
# 100
# Harrell
# 213.05424
# paid
# Lansing-East Lansing, MI
# <class 'str'>
# Not In Love
# 97
# Cage The Elephant
# Kate
# F
# 101
# Harrell
# 175.12444
# paid
# Lansing-East Lansing, MI
# <class 'str'>
# Ain't No Rest For The Wicked (Original Version)
# 97
# Rick Ross
# Kate
# F
# 102
# Harrell
# 277.36771
# paid
# Lansing-East Lansing, MI
# <class 'str'>
# Luxury Tax
# 97
# Lovehatehero
# Kaylee
# F
# 0
# Summers
# 216.65914
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Red Dress
# 8
# Justin Bieber
# Kaylee
# F
# 1
# Summers
# 264.35873
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Never Let You Go
# 8
# Zero 7
# Kaylee
# F
# 2
# Summers
# 199.96689
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# You're My Flame [Album Version]
# 8
# Yeah Yeah Yeahs
# Kaylee
# F
# 3
# Summers
# 220.96934
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Heads Will Roll
# 8
# 4 Skins
# Kaylee
# F
# 4
# Summers
# 165.51138
# free
# Phoenix-Mesa-Scottsdale, AZ
# <class 'str'>
# Clockwork Skinhead
# 8
# Anne-Lie RydÃÂ©
# Wyatt
# M
# 0
# Scott
# 176.90077
# free
# Eureka-Arcata-Fortuna, CA
# <class 'str'>
# SÃÂ¥n't ÃÂr Livet (You Can Have Her) (2002 Digital Remaster)
# 9
# The Smiths
# Wyatt
# M
# 1
# Scott
# 242.9122
# free
# Eureka-Arcata-Fortuna, CA
# <class 'str'>
# There Is A Light That Never Goes Out
# 9
# Metallica
# Wyatt
# M
# 2
# Scott
# 515.21261
# free
# Eureka-Arcata-Fortuna, CA
# <class 'str'>
# Master Of Puppets
# 9
# Flight Of The Conchords
# Kynnedi
# F
# 0
# Sanchez
# 148.55791
# free
# Cedar Rapids, IA
# <class 'str'>
# Too Many Dicks (On The Dance Floor)
# 89
# In Flames
# Kynnedi
# F
# 1
# Sanchez
# 255.76444
# free
# Cedar Rapids, IA
# <class 'str'>
# ...
# <class 'str'>
# Day Job
# 88
# Che Sudaka
# Jacob
# M
# 22
# Klein
# 160.49587
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Bihotza
# 73
# Audioslave
# Lily
# F
# 1
# Burns
# 273.65832
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Yesterday To Tomorrow
# 32
# Erin Bode
# Jacob
# M
# 23
# Klein
# 252.05506
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Here_ There And Everywhere
# 73
# Calle 13
# Mohammad
# M
# 1
# Rodriguez
# 239.3073
# free
# Sacramento--Roseville--Arden-Arcade, CA
# <class 'str'>
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Master Of Puppets
# 73
# Bikini Kill
# Jacob
# M
# 43
# Klein
# 149.81179
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Reject All American
# 73
# The Black Keys
# Jacob
# M
# 44
# Klein
# 204.59057
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Every Lasting Light
# 73
# Jake Hess
# Jacob
# M
# 45
# Klein
# 199.26159
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# You And Me Jesus
# 73
# B.o.B
# Jacob
# M
# 46
# Klein
# 269.63546
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Nothin' On You [feat. Bruno Mars] (Album Version)
# 73
# Collective Soul
# Jacob
# M
# 47
# Klein
# 155.29751
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Reunion (LP Version)
# 73
# Three Drives
# Jacob
# M
# 48
# Klein
# 411.6371
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Greece 2000
# 73
# Vanity Fare
# Jacob
# M
# 49
# Klein
# 152.86812
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Early In The Morning
# 73
# Drake / Kanye West / Lil Wayne / Eminem
# Jacob
# M
# 50
# Klein
# 357.66812
# paid
# Tampa-St. Petersburg-Clearwater, FL
# <class 'str'>
# Forever
# 73
# Aleks Syntek
# Stefany
# F
# 1
# White
# 300.14649
# free
# Lubbock, TX
# <class 'str'>
# Tu Necesitas (2008 Digital Remaster)
# 83
# The Grapes Of Wrath
# Stefany
# F
# 2
# White
# 138.05669
# free
# Lubbock, TX
# <class 'str'>
# All The Things I Wasn't
# 83
# Rilo Kiley
# Stefany
# F
# 3
# White
# 215.64036
# free
# Lubbock, TX
# <class 'str'>
# Silver Lining (Album Version)
# 83
# Lonnie Gordon
# Stefany
# F
# 4
# White
# 181.21098
# free
# Lubbock, TX
# <class 'str'>
# Catch You Baby (Steve Pitron & Max Sanna Radio Edit)
# 83
# Matt Costa
# Ava
# F
# 0
# Robinson
# 246.02077
# free
# New Haven-Milford, CT
# <class 'str'>
# Unfamiliar Faces
# 50
# Capital Inicial
# Jaleah
# F
# 0
# Hayes
# 228.67546
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# FÃÂ¡tima
# 70
# A Day To Remember
# Jaleah
# F
# 2
# Hayes
# 243.22567
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# If It Means A Lot To You
# 70
# Jack Johnson
# Jaleah
# F
# 3
# Hayes
# 236.93016
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Bubble Toes
# 70
# Gorillaz
# Jaleah
# F
# 4
# Hayes
# 246.17751
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# DARE
# 70
# Jason Mraz
# Jaleah
# F
# 5
# Hayes
# 220.18567
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# You And I Both (LP Version)
# 70
# Ligabue
# Jaleah
# F
# 6
# Hayes
# 246.20363
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# I duri hanno due cuori
# 70
# Steve Miller Band
# Jaleah
# F
# 7
# Hayes
# 306.23302
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Abracadabra
# 70
# 38 Special
# Jaleah
# F
# 8
# Hayes
# 280.76363
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Caught Up In You
# 70
# Wonderwall
# Jaleah
# F
# 9
# Hayes
# 281.02485
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Just More (Album Version)
# 70
# Pepper
# Jaleah
# F
# 10
# Hayes
# 166.32118
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Slave
# 70
# Buckcherry
# Jaleah
# F
# 11
# Hayes
# 208.66567
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Next 2 You (Album Version)
# 70
# Travie McCoy
# Jaleah
# F
# 12
# Hayes
# 211.12118
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Billionaire [feat. Bruno Mars]  (Explicit Album Version)
# 70
# OneRepublic
# Jaleah
# F
# 13
# Hayes
# 224.67873
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Secrets
# 70
# Hawk Nelson
# Chloe
# F
# 0
# Cuevas
# 174.81098
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# California
# 49
# Pearl Jam
# Jaleah
# F
# 14
# Hayes
# 258.48118
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Faithful
# 70
# JOSEF LOCKE & ORCHESTRA
# Chloe
# F
# 1
# Cuevas
# 166.26893
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# How Can You Buy Killarney (1992 Digital Remaster)
# 49
# Project 86
# Chloe
# F
# 2
# Cuevas
# 777.58649
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Twenty Three (LP Version)
# 49
# Daft Punk
# Jaleah
# F
# 15
# Hayes
# 536.13669
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Revolution 909 (Roger Sanchez Remix)
# 70
# 38 Special
# Jaleah
# F
# 16
# Hayes
# 280.76363
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Caught Up In You
# 70
# Creedence Clearwater Revival
# Chloe
# F
# 4
# Cuevas
# 186.51383
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# Proud Mary
# 49
# Ill Nino
# Jaleah
# F
# 17
# Hayes
# 175.22893
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# My Resurrection (Album Version)
# 70
# The Police
# Chloe
# F
# 5
# Cuevas
# 289.85424
# paid
# San Francisco-Oakland-Hayward, CA
# <class 'str'>
# So Lonely
# 49
# Bitter:Sweet
# Jaleah
# F
# 18
# Hayes
# 160.78322
# paid
# San Antonio-New Braunfels, TX
# <class 'str'>
# Take 2 Blue
# 70
# Frumpies
# Anabelle
# F
# 0
# Simpson
# 134.47791
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# Hello Kitty
# 69
# Kenny G with Peabo Bryson
# Anabelle
# F
# 1
# Simpson
# 264.75057
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# By The Time This Night Is Over
# 69
# Biffy Clyro
# Anabelle
# F
# 2
# Simpson
# 189.83138
# free
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# <class 'str'>
# God & Satan
# 69
# HIM
# Lily
# F
# 1
# Burns
# 212.06159
# free
# New York-Newark-Jersey City, NY-NJ-PA
# <class 'str'>
# Beautiful
# 32
# Matmos
# Joseph
# M
# 0
# Gutierrez
# 1449.11628
# free
# Columbia, SC
# <class 'str'>
# Supreme Balloon
# 75
# Gary Allan
# Ryann
# F
# 0
# Smith
# 259.83955
# free
# Palestine, TX
# <class 'str'>
# The One
# 92
# Miracle Fortress
# Ryann
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Alive (2006 Remastered Album Version)
# 44
# Bloc Party
# Aleena
# F
# 6
# Kirby
# 222.04036
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Plans (Replanned by Mogwai)
# 44
# Los Prisioneros
# Aleena
# F
# 7
# Kirby
# 211.12118
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Pa Pa Pa
# 44
# Octopus Project
# Aleena
# F
# 8
# Kirby
# 175.25506
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Lots More Stairs
# 44
# Roudoudou
# Aleena
# F
# 9
# Kirby
# 18.41587
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Ecoute Ce Scratch
# 44
# Africando
# Aleena
# F
# 10
# Kirby
# 253.54404
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Tierra Tradicional
# 44
# RUN-DMC Featuring Method Man_ Kenny Cash_ Mike Ransom_ and Jamel Simmons
# Aleena
# F
# 11
# Kirby
# 266.52689
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Simmons Incorporated
# 44
# Graham Coxon
# Colm
# M
# 1
# Santana
# 197.14567
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# I'm Goin' Away
# 67
# Queens Of The Stone Age
# Aleena
# F
# 12
# Kirby
# 231.02649
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# In The Fade
# 44
# Dance Gavin Dance
# Colm
# M
# 2
# Santana
# 193.30567
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# Strawberry AndrÃÂ© (Album Version)
# 67
# Passion Pit
# Aleena
# F
# 13
# Kirby
# 243.69587
# paid
# Waterloo-Cedar Falls, IA
# <class 'str'>
# Eyes As Candles
# 44
# Black Eyed Peas
# Colm
# M
# 4
# Santana
# 229.61587
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# Let's Get It Started
# 67
# Plastic Bertrand
# Colm
# M
# 5
# Santana
# 180.00934
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# Ca plane pour moi
# 67
# Cream
# Colm
# M
# 6
# Santana
# 166.5824
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# Strange Brew
# 67
# Coldplay
# Colm
# M
# 7
# Santana
# 284.39465
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# A Message
# 67
# Cute Is What We Aim For
# Colm
# M
# 8
# Santana
# 172.22485
# free
# Nashville-Davidson--Murfreesboro--Franklin, TN
# <class 'str'>
# Sweat the Battle Before the Battle Sweats You (Album Version)
# 67
# Metallica
# Connar
# M
# 0
# Moreno
# 256.9922
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Of Wolf And Man
# 62
# The Kills
# Connar
# M
# 1
# Moreno
# 217.70404
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Tape Song
# 62
# Foo Fighters
# Connar
# M
# 2
# Moreno
# 271.38567
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# The Pretender
# 62
# Plaid
# Connar
# M
# 3
# Moreno
# 260.96281
# free
# Houston-The Woodlands-Sugar Land, TX
# <class 'str'>
# Eyen [Chosen by fans on Warp20.net]
# 62
# The Van Pelt
# Theodore
# M
# 1
# Harris
# 208.71791
# free
# Red Bluff, CA
# <class 'str'>
# It's New To Me
# 14
# 44
# Ryan
# M
# 1
# Smith
# 224.57424
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# Make You Smile
# 26
# Chris Brown
# Rylan
# M
# 1
# George
# 275.1473
# free
# Birmingham-Hoover, AL
# <class 'str'>
# I May Never Find
# 16
# KT Tunstall
# Ryan
# M
# 2
# Smith
# 170.47465
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# Black Horse And The Cherry Tree (Radio Version)
# 26
# Cascada
# Rylan
# M
# 2
# George
# 184.39791
# free
# Birmingham-Hoover, AL
# <class 'str'>
# Kids In America
# 16
# Incubus
# Ryan
# M
# 3
# Smith
# 293.38077
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# Black Heart Inertia
# 26
# Miike Snow
# Tegan
# F
# 1
# Levine
# 220.83873
# paid
# Portland-South Portland, ME
# <class 'str'>
# Black & Blue
# 80
# Cartola
# Tegan
# F
# 2
# Levine
# 208.92689
# paid
# Portland-South Portland, ME
# <class 'str'>
# Sala De RecepÃÂ§ÃÂ£o
# 80
# Kill The Client
# Tegan
# F
# 3
# Levine
# 70.68689
# paid
# Portland-South Portland, ME
# <class 'str'>
# Commander In Thief
# 80
# Wolfmother
# Tegan
# F
# 5
# Levine
# 175.82975
# paid
# Portland-South Portland, ME
# <class 'str'>
# Woman
# 80
# Old Crow Medicine Show
# Tegan
# F
# 6
# Levine
# 231.73179
# paid
# Portland-South Portland, ME
# <class 'str'>
# Wagon Wheel
# 80
# Architecture In Helsinki
# Tegan
# F
# 7
# Levine
# 173.73995
# paid
# Portland-South Portland, ME
# <class 'str'>
# Debbie
# 80
# Charlie Louvin
# Tegan
# F
# 8
# Levine
# 170.86649
# paid
# Portland-South Portland, ME
# <class 'str'>
# I Think I'll Live
# 80
# Miguel Morales
# Tegan
# F
# 9
# Levine
# 270.78485
# paid
# Portland-South Portland, ME
# <class 'str'>
# La Derrota de Un Don Juan
# 80
# Dominique A
# Tegan
# F
# 10
# Levine
# 153.20771
# paid
# Portland-South Portland, ME
# <class 'str'>
# Le Courage Des Oiseaux
# 80
# Cock Sparrer
# Tegan
# F
# 11
# Levine
# 203.25832
# paid
# Portland-South Portland, ME
# <class 'str'>
# Run With The Blind
# 80
# Jimmy Wakely
# Tegan
# F
# 12
# Levine
# 165.74649
# paid
# Portland-South Portland, ME
# <class 'str'>
# I Love You So Much It Hurts
# 80
# Peter Doherty
# Tegan
# F
# 13
# Levine
# 217.02485
# paid
# Portland-South Portland, ME
# <class 'str'>
# A Little Death Around the Eyes
# 80
# Katy Perry
# Tegan
# F
# 14
# Levine
# 246.41261
# paid
# Portland-South Portland, ME
# <class 'str'>
# Thinking Of You
# 80
# Sidewalk Prophets
# Molly
# F
# 0
# Taylor
# 260.62322
# free
# St. Louis, MO-IL
# <class 'str'>
# You Love Me Anyway (Album)
# 35
# Rise Against
# Molly
# F
# 1
# Taylor
# 221.17832
# free
# St. Louis, MO-IL
# <class 'str'>
# Torches
# 35
# K'Naan
# Molly
# F
# 2
# Taylor
# 220.49914
# free
# St. Louis, MO-IL
# <class 'str'>
# Wavin'  Flag
# 35
# Patrick Jumpen
# Ryan
# M
# 0
# Smith
# 208.87465
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# Holiday
# 26
# Alicia Keys
# Ryan
# M
# 1
# Smith
# 216.47628
# free
# San Jose-Sunnyvale-Santa Clara, CA
# <class 'str'>
# Empire State Of Mind (Part II) Broken Down
# 26

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
              
query = "select artist, song, length  from music_events WHERE sessionId = 338 AND itemInSession = 4"
try:
    rows = session.execute(query)
except Exception as e:
    print(e)
    
for row in rows:
    print (row.artist, row.song, row.length,)
# Out:
# Faithless Music Matters (Mark Knight Dub) 495.30731201171875

# %% [markdown]
# ### COPY AND REPEAT THE ABOVE THREE CELLS FOR EACH OF THE THREE QUESTIONS

# %%
## TO-DO: Query 2: Give me only the following: name of artist, song (sorted by itemInSession) and user (first and last name)\
## for userid = 10, sessionid = 182


query = "CREATE TABLE IF NOT EXISTS user_music_events "
query = query + """(artist text, song text, firstname text, lastname text, userId int, sessionId int, itemInSession int, 
PRIMARY KEY ((userid, sessionId), itemInSession))"""

session.execute(query)

# %%
# We have provided part of the code to set up the CSV file. Please complete the Apache Cassandra code below#
file = 'event_datafile_new.csv'

with open(file, encoding = 'utf8') as f:
    csvreader = csv.reader(f)
    next(csvreader) # skip header
    for line in csvreader:
## TO-DO: Assign the INSERT statements into the `query` variable
        query = "INSERT INTO user_music_events (artist, song, firstname, lastname, userId, sessionId, itemInSession) "
        query = query + " VALUES (%s, %s, %s, %s, %s, %s, %s)"
        ## TO-DO: Assign which column element should be assigned for each column in the INSERT statement.
        ## For e.g., to INSERT artist_name and user first_name, you would change the code below to `line[0], line[1]`
        session.execute(query, (line[0], line[9], line[1], line[4], int(line[10]), int(line[8]), int(line[3])))

# %% [markdown]
# #### Do a SELECT to verify that the data have been inserted into each table

# %%
## TO-DO: Add in the SELECT statement to verify the data was entered into the table
              
query = "select artist, song, firstname, lastname from user_music_events WHERE  userId = 10 AND sessionId = 182 "
try:
    rows = session.execute(query)
except Exception as e:
    print(e)
    
for row in rows:
    print (row.artist, row.song, row.firstname,row.lastname)
# Out:
# Down To The Bone Keep On Keepin' On Sylvie Cruz
# Three Drives Greece 2000 Sylvie Cruz
# Sebastien Tellier Kilometer Sylvie Cruz
# Lonnie Gordon Catch You Baby (Steve Pitron & Max Sanna Radio Edit) Sylvie Cruz

# %%
## TO-DO: Query 3: Give me every user name (first and last) in my music app history who listened to the song 'All Hands Against His Own'

# %% [markdown]
# ### Drop the tables before closing out the sessions

# %%
## TO-DO: Drop the table before closing out the sessions

# %%
query = "drop table user_music_events"
try:
    rows = session.execute(query)
except Exception as e:
    print(e)

# %% [markdown]
# ### Close the session and cluster connection¶

# %%
session.shutdown()
cluster.shutdown()
